# %% [markdown]
# ## ESTATÍSTICA DESCRITIVA
#
#                                                                             Bruno Bastos
#                                                                             Matheus Olimpio
#
# ---
# #### Cenário
#
# #### Variáveis
#
#
# #### Tabela

# %%
CsvI.tableDescrib()
# Out:
# +-------------------------------------------+-------+
# |                   Título                  | Sigla |
# +-------------------------------------------+-------+
# |   OCORRÊNCIAS DE PORTE DE ENTORPECENTES   |  OPE  |
# |  OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES  |  OTE  |
# | OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES |  OAE  |
# |    OCORRÊNCIAS DE PORTE ILEGAL DE ARMA    |  OPIA |
# |      Nº DE ARMAS DE FOGO APREENDIDAS      |  NAFA |
# |         Nº DE FLAGRANTES LAVRADOS         |  NFL  |
# | Nº DE INFRATORES APREENDIDOS EM FLAGRANTE |  NIAF |
# |  Nº DE INFRATORES APREENDIDOS POR MANDADO |  NIAM |
# |     Nº DE PESSOAS PRESAS EM FLAGRANTE     |  NPPF |
# |      Nº DE PESSOAS PRESAS POR MANDADO     |  NPPM |
# |          Nº DE PRISÕES EFETUADAS          |  NPE  |
# |         Nº DE VEÍCULOS RECUPERADOS        |  NVR  |
# |  TOT. DE INQUÉRITOS POLICIAIS INSTAURADOS |  TIPI |
# +-------------------------------------------+-------+

# %% [markdown]
# ### Análise dos departamentos
#
# - No ano de 2017 e 2018 com todos os meses
# - No ano de 2017, 2018 e 2019 com os dois primeiros meses

# %%
Facade.showDepartamentByYear()
# Out:
# Quantidade de ocorrencias
# +------+------+-------+
# | 2017 | 2018 | total |
# +------+------+-------+
# | 564  | 461  |  1025 |
# +------+------+-------+

# %% [markdown]
# ---

# %%
Facade.showDepartamentJanFeb()
# Out:
# Quantidade de ocorrencias em Jan e Fev
# +--------------+------+------+------+
# | departamento | 2017 | 2018 | 2019 |
# +--------------+------+------+------+
# |     DP01     |  30  |  39  |  50  |
# |     DP02     |  43  |  34  |  24  |
# |     DP03     |  36  |  20  |  28  |
# +--------------+------+------+------+

# %% [markdown]
# ###### 4.1 Análise das Ocorrencias
# - Tipo de registro em cada departamento por ano
# - Maior ocorrencia  e acompanhamento por grafico nos 12 meses

# %%
Facade.showThreeOcurrenceByYear()
# Out:
# Categoria maior ocorrencia em 2017
# +--------------+----------+------------+
# | Departamento | Natureza | Quantidade |
# +--------------+----------+------------+
# |     DP01     |   NPPF   |     86     |
# |     DP02     |   NPPF   |     61     |
# |     DP03     |   NPPF   |     40     |
# +--------------+----------+------------+
# Categoria maior ocorrencia em 2018
# +--------------+----------+------------+
# | Departamento | Natureza | Quantidade |
# +--------------+----------+------------+
# |     DP01     |   NPPF   |     66     |
# |     DP02     |   NPPF   |     49     |
# |     DP03     |   OTE    |     33     |
# +--------------+----------+------------+
# Categoria maior ocorrencia em 2019
# +--------------+----------+------------+
# | Departamento | Natureza | Quantidade |
# +--------------+----------+------------+
# |     DP01     |   NPPF   |     18     |
# |     DP02     |   NFL    |     7      |
# |     DP03     |   OTE    |     10     |
# +--------------+----------+------------+

# %%
Facade.showMostOcurrenceDevByYear('NPPF',['2017','2018','2019'],'pessoas presas em flagrante','grb')

# %%
Facade.showMostOcurrenceDevByYear('OTE',['2017','2018','2019'],'Tráfico de drogas','grb')

# %%
class Facade:
    
    @staticmethod
    def showDepartamentByYear():
        s1, s2 = MathI.pizzaYear([DP01, DP02, DP03], '2017')
        s3, s4 = MathI.pizzaYear([DP01, DP02, DP03], '2018')
        #s5, s6 = MathI.pizzaYear([DP01, DP02, DP03], '2019')
        MathI.drawPizzaYear([[s1,s2],[s3,s4]])
        CsvI.table([[s1, s3,(s1 + s3)]], ['2017','2018','total'], None, title= 'Quantidade de ocorrencias')
        
    @staticmethod
    def showDepartamentJanFeb():
        data = MathI.pizzaMonth([DP01, DP02, DP03], [1,2], ['2017','2018','2019'])
        MathI.drawPizzaMonth(data,['DP01','DP02','DP03'],['2017','2018','2019'])
        CsvI.table(data,['departamento','2017','2018','2019'],['DP01','DP02','DP03'],title='Quantidade de ocorrencias em Jan e Fev')
        
    @staticmethod
    def showThreeOcurrenceByYear():
        x1 = MathI.threeMore([DP01, DP02, DP03], '2017')
        x2 = MathI.threeMore([DP01, DP02, DP03], '2018')
        x3 = MathI.threeMore([DP01, DP02, DP03], '2019')
        CsvI.table(x1,['Departamento','Natureza','Quantidade'],['DP01','DP02','DP03'],'Categoria maior ocorrencia em 2017')
        CsvI.table(x2,['Departamento','Natureza','Quantidade'],['DP01','DP02','DP03'],'Categoria maior ocorrencia em 2018')
        CsvI.table(x3,['Departamento','Natureza','Quantidade'],['DP01','DP02','DP03'],'Categoria maior ocorrencia em 2019')
        
    @staticmethod
    def showMostOcurrenceDevByYear(name, year, title, c):
        array = []
        if type(year) is list:
            for x in range(len(year)):
                array.append(MathI.ocurrenceYear(name, year[x]))
        else:
            array.append(MathI.ocurrenceYear(name, year))
        meses = ['Jan', 'Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
        for x in range(len(array)):
            plt.plot(meses, array[x], color=c[x], label=year[x])
        plt.legend(loc='upper left')
        plt.xlabel('Meses')
        plt.ylabel('Quantidade')
        plt.title(title)
        plt.show()

# %%
import csv
from prettytable import PrettyTable

# CSV Implementation 
class CsvI:
    
    @staticmethod
    def read(file):
        matrix = []
        
        with open(file, encoding="utf8") as csvFile:
            reader = csv.reader(csvFile)
            for row in reader:
                matrix.append(row)
            csvFile.close()
        
        return matrix
    
    @staticmethod 
    def msg(title, msg):
        print("{0} {1}". format(title, msg))
        
    @staticmethod
    def table(datas, titles, params = None, title = None):
        x = PrettyTable()
        x.field_names= titles
        if datas is not None:
            if title is not None:
                print(title)
            if params is not None:
                for i in range(len(datas)):
                    array = []
                    array.append(params[i])
                    for j in range(len(datas[i])):
                        array.append(datas[i][j])
                    x.add_row(array)
            else:
                for i in range(len(datas)):
                    array = []
                    for j in range(len(datas[i])):
                        array.append(datas[i][j])
                    x.add_row(datas[i])
        
        print(x)
    
    @staticmethod
    def tableDescrib():
        x = PrettyTable()
        colunas = ['Título','Sigla']
        x.field_names = colunas

        x.add_row(['OCORRÊNCIAS DE PORTE DE ENTORPECENTES','OPE']);
        x.add_row(['OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES','OTE']);
        x.add_row(['OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES','OAE']);
        x.add_row(['OCORRÊNCIAS DE PORTE ILEGAL DE ARMA','OPIA']);
        x.add_row(['Nº DE ARMAS DE FOGO APREENDIDAS','NAFA']);
        x.add_row(['Nº DE FLAGRANTES LAVRADOS','NFL']);
        x.add_row(['Nº DE INFRATORES APREENDIDOS EM FLAGRANTE','NIAF']);
        x.add_row(['Nº DE INFRATORES APREENDIDOS POR MANDADO','NIAM']);
        x.add_row(['Nº DE PESSOAS PRESAS EM FLAGRANTE','NPPF']);
        x.add_row(['Nº DE PESSOAS PRESAS POR MANDADO','NPPM']);
        x.add_row(['Nº DE PRISÕES EFETUADAS','NPE']);
        x.add_row(['Nº DE VEÍCULOS RECUPERADOS','NVR']);
        x.add_row(['TOT. DE INQUÉRITOS POLICIAIS INSTAURADOS','TIPI']);

        print(x)

DP01 = {
    '2017': CsvI.read('./data/DP012017.csv'),
    '2018' : CsvI.read('./data/DP012018.csv'),
    '2019' : CsvI.read('./data/DP012019.csv')
}
DP02 = {
    '2017': CsvI.read('./data/DP022017.csv'),
    '2018' : CsvI.read('./data/DP022018.csv'),
    '2019' : CsvI.read('./data/DP022019.csv')
}
DP03= {
    '2017': CsvI.read('./data/DP032017.csv'),
    '2018' : CsvI.read('./data/DP032018.csv'),
    '2019' : CsvI.read('./data/DP032019.csv')
}

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas


#Math Implementation
class MathI:
    
    #Mounthly Average
    @staticmethod
    def monAvg(data):
        pass
    # total Average /with all years for all departaments/
    @staticmethod
    def totalAvg(data):
        pass
    @staticmethod
    def ocurrenceYear(name, year):
        array = [DP01, DP02, DP03]
        soma = [0 for x in range(12)]
        for aux in range(len(array)):
            for line in range(len(array[aux][year])):
                if(array[aux][year][line][0] == name):
                    for collum in range(1,13):
                        soma[collum-1] += int(array[aux][year][line][collum])
        return soma
            
    @staticmethod
    def pizzaYear(array, year):
        res = []
        for aux in range(len(array)):
            res.append(aux)
            res[aux] = 0
            for line in range(1,11):
                res[aux] += int(array[aux][year][line][13])
        soma = 0
        size = []
        for aux in range(len(res)):
            soma += res[aux]
        
        for aux in range(len(res)):
            size.append((res[aux] * 100)/soma)
        return [soma, size]
    
    @staticmethod
    def pizzaMonth(array, months, years):
        res = []
        for aux in range(len(array)):
            res.append(aux)
            res[aux] = []
            for year in range(len(years)):
                soma = 0
                for line in range(1,11):
                    for m in range(len(months)):
                        soma += int(array[aux][years[year]][line][m + 1]) 
                res[aux].append(soma)
        return res
    
    def threeMore(array, year):
        aux = []
        for i in range(len(array)):
            maximo = 0
            ind = 0
            for line in range(1, 11):
                #print(array[i][year][line][13])
                if (int(array[i][year][line][13])) > int(maximo) :
                    maximo = array[i][year][line][13]
                    ind = array[i][year][line][0]
            l = [ind, maximo]
            aux.append(l)
        return aux
            
    def occurrenceYear(array, year):
        print(array[0][year])
        
    @staticmethod
    def drawPizzaMonth(datas, column, labels):
        x = []
        x.append((datas[0][0], datas[1][0], datas[2][0]))
        x.append((datas[0][1], datas[1][1], datas[2][1]))
        x.append((datas[0][2], datas[1][2], datas[2][2]))
        fig, axs = plt.subplots(1,len(x), figsize=(10,10), sharex='col', sharey='row')
        for i in range(len(x)):
            wedges, texts, autotexts = axs[i].pie(x[i], labels=['Dep 01','Dep 02', 'Dep 03'],startangle=90, autopct='%1.2f%%', shadow=True)
            axs[i].set_title(labels[i])
            plt.setp(autotexts, size=12, weight="bold", color='w')
        #fig.suptitle("Title for whole figure")
        #fig.suptitle('Distribuição de frequencia por departamento em Janeiro e Fevereiro',pad=53.0,loc='right',fontsize=5)
        plt.show()

    @staticmethod
    def drawPizzaYear(array):   
        fig, axs = plt.subplots(1,len(array),figsize=(10,10), sharex='col', sharey='row')
        for x in range(len(array)):
            wedges, texts, autotexts = axs[x].pie(array[x][1], labels=['Dep 01','Dep 02', 'Dep 03'],startangle=90, autopct='%1.2f%%\n', shadow=True)
            plt.setp(autotexts, size=14, weight="bold", color='w')
        plt.title('Distribuição de frequencia por departamento no ano de {0}'. format('2017 | 2018'))
        plt.show()
# Out:
# [14, 19, 13, 9, 17, 15, 18, 22, 15, 25, 10, 10]
